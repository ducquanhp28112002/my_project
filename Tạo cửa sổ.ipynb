# %%
from tkinter import *
from tkinter.ttk import *

root = Tk()
root.title("Waiter management system")
root.geometry("625x150")

name_label = Label(root, text = "Name:")
name_label.place(x = 20, y = 5)

quantity_label = Label(root, text = "Quantity:")
quantity_label.place(x = 20, y = 25)

time_label = Label(root, text = "To time:")
time_label.place(x = 20, y = 45)

name_entry = Entry(root)
name_entry.place(x = 120, y = 5)

quantity_entry = Entry(root)
quantity_entry.place(x = 120, y = 25)

time_entry = Entry(root)
time_entry.place(x = 120, y = 45)

add_button = Button(root, text = "Add", command = None)
add_button.place(x = 20, y = 65)

delete_button = Button(root, text = "Delete", command = None)
delete_button.place(x = 140, y = 65)

reset_button = Button(root, text = "Reset", command = None)
reset_button.place(x = 260, y = 65)

search_button = Button(root, text = "Search", command = None)
search_button.place(x = 140, y = 85)

add_entry = Entry(root)
add_entry.place(x = 0, y = 85)

need_label = Label(root, text = "I need waiter")
need_label.place(x = 20, y = 110)

combo1 = Combobox(root)
combo1.place(x = 120, y = 110)

combo2 = Combobox(root)
combo2.place(x = 260, y = 110)

combo3 = Combobox(root)
combo3.place(x = 400, y = 110)

submit_button = Button(root, text = "Submit", command = None)
submit_button.place(x = 545, y = 110)

root.mainloop()
